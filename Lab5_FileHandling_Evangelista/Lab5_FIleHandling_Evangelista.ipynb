# %%
# Procedure 1: Writing to a File

# Step 1: Import Path from pathlib
from pathlib import Path

# Step 2: Define a custom folder in your Documents directory
output_dir = Path.home() / "Documents" / "Evangelista_Activity_5"
output_dir.mkdir(exist_ok=True) # Creates folder if missing

# Step 3: Define the file path
file_path = output_dir / "Act5_example.txt"

# Step 4: Write text to the file
with open(file_path, "w", encoding="utf-8") as file:
    file.write("Hello, Welcome to Python Programming!\n")
    file.write("File saved safely with pathlib.\n")
    file.write("Python makes file handling easy!\n")

# Step 5: Confirm that the file is saved
print(f"File saved to: {file_path.resolve()}")
# Out:
# File saved to: C:\Users\gian\Documents\Evangelista_Activity_5\Act5_example.txt

# %%
# Updated Procedure 2: Reading from a file with filters and word counts

# Step 2: Read line-by-line
with open(file_path, "r", encoding="utf-8") as file:
    print("--- Try It Results ---")
    for line_number, line in enumerate (file, 1):
        clean_line = line.strip()           #remove extra spaces/newlines
        words = clean_line.split()          #split into words
        word_count = len(words)             #count words
        if "Python" in clean_line:          #filter lines containing "Python"
            print(f"Line {line_number} (Words: {word_count}): {clean_line}")
# Out:
# --- Try It Results ---
# Line 1 (Words: 5): Hello, Welcome to Python Programming!

# %%
# Procedure 3: Appending Data

# Step 1: Open file in append mode
with open(file_path, "a", encoding="utf-8") as file:
    file.write("\nThis line was added!")
    
    # Try It: Append multiple lines using a list and file.writelines().
    extra_lines = [
        "\nAdding more content via list.",
        "\nFile handling in Python is powerful!"
    ]
    file.writelines (extra_lines)

    # Try It: Ask the user for input and append that to the file.
    user_note = input("Enter a sentence to add to your file: ")
    file.write(f"\nUser added: {user_note}")
    
# Step 2: Confirm that data was added
print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
# Procedure 4: Safe File Operations with Backup

# Step 1: Import additional libraries
from pathlib import Path
import shutil
from datetime import datetime

student_id = "2025-0295"

# Step 2: Define working directory
backup_dir = Path.home() / "Documents" / "Evangelista_Activity_5" / f"backup_{student_id}"
backup_dir.mkdir(exist_ok=True, parents=True)

# Search for files that start with the filename and contain 'backup'
def write_with_backup(filename_str, content):
    # Convert the string filename to a Path object to use .stem and .suffix
    filename = Path(filename_str)
    # We must ensure we are looking in the correct output directory
    full_path = Path.home() / "Documents" / "Evangelista_Activity_5" / filename
    
    # Create a unique backup name using a timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    backup_name = f"{full_path.stem}_Evangelista_backup_{timestamp}{full_path.suffix}"
    backup_path = backup_dir / backup_name

    # Step 1: Create a backup of the existing file
    if full_path.exists():
        shutil.copy(full_path, backup_path)
        print(f"Backup created: {backup_path.name}")

    # Step 2: Write new content to the original file
    with open(full_path, "w", encoding="utf-8") as file:
        file.write(content)
    print(f"File '{full_path.name}' updated successfully.")

# Step 3: Define function to list specific backups
def list_specific_backups(filename_str):
    filename = Path(filename_str)
    print(f"\n--- Backups for {filename.name} ---")
    # Search pattern for glob
    search_pattern = f"{filename.stem}_backup*"
    for backup in backup_dir.glob(search_pattern):
        print("-", backup.name)

# --- Execution Section ---
print("=== File Operations Demo ===")

# 1. Initial creation
print("\n1. Creating new file:")
write_with_backup("demo.txt", "Initial content")

# 2. Update (This will trigger the backup)
print("\n2. Updating file (with backup):")
write_with_backup("demo.txt", "Updated content")

# 3. Listing backups
list_specific_backups("demo.txt")
# Out:
# === File Operations Demo ===
#
# 1. Creating new file:
# File 'demo.txt' updated successfully.
#
# 2. Updating file (with backup):
# Backup created: demo_Evangelista_backup_20260420_022939.txt
# File 'demo.txt' updated successfully.
#
# --- Backups for demo.txt ---

# %%
# Procedure 5: Menu-Driven File Manager
# Step 1: Import required modules
from pathlib import Path
from datetime import datetime
import shutil

# Step 2: Define your custom working directory in Documents 
backup_dir = Path.home() / "Documents" / "Evangelista_Activity_5" 
backup_dir.mkdir(exist_ok=True)  # Create folder if it doesn’t exist 

# Step 3: Define the menu-driven file manager 
def file_manager(): 
    file_name = input("Enter filename (e.g., notes.txt): ") 
    file_path = backup_dir / file_name 

    while True: 
        print("\n--- MENU ---") 
        print("1. Write to file") 
        print("2. Append to file") 
        print("3. Read file") 
        print("4. Backup files")
        print("5. List all backup files") 
        print("6. Exit") 

        choice = input("Choose an option (1-6): ") 

        if choice == "1": 
            content = input("Enter content to write:\n") 
            with open(file_path, "w", encoding="utf-8") as f: 
               f.write(content) 
            print("File written successfully.") 

        elif choice == "2": 
            more = input("Enter content to append:\n") 
            with open(file_path, "a", encoding="utf-8") as f: 
                f.write("\n" + more) 
            print("Content appended.") 

        elif choice == "3": 
            if file_path.exists(): 
                with open(file_path, "r", encoding="utf-8") as f: 
                    print("\nFile Content:\n", f.read())
            else: 
                print("File not found.") 

        elif choice == "4": 
            if file_path.exists(): 
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S") 
                backup_file = file_path.with_name( 
                    f"{file_path.stem}_backup_{timestamp}{file_path.suffix}" 
                ) 
                shutil.copy2(file_path, backup_file) 
                print(f"Backup created: {backup_file.name}") 
            else: 
                print("Cannot backup. File does not exist.") 

        elif choice == "5": 
            # Try It: Add a menu option to list all backup files
            print(f"\n--- All Backups in {backup_dir.name} ---")
            for backup in backup_dir.glob("backup"):
                print("-", backup.name)
        
        elif choice == "6": 
            print("Exiting the file manager.") 
            break 

        else: 
            print("Invalid choice. Please try again.") 
            
# Step 4: Run the menu-driven tool 
if __name__ == "__main__": 
    file_manager()
# Out:
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup files
# 5. List all backup files
# 6. Exit
# Content appended.
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup files
# 5. List all backup files
# 6. Exit
# Backup created: 1_backup_20260426_234456
#
# --- MENU ---
# 1. Write to file
# 2. Append to file
# 3. Read file
# 4. Backup files
# 5. List all backup files
# 6. Exit
# Exiting the file manager.

# %%
# IV. DATA AND OBSERVATION 1

# Create and Write to a File 
from pathlib import Path 
 
student_id = "2025-0295" 
student_name = "Gian Evangelista"
 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
documents_path.mkdir(parents=True, exist_ok=True) 
 
file_path = documents_path / f"intro_{student_id}.txt" 
file_path.write_text(f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!") 
 
print(f"File created and text written at: {file_path}")
# Out:
# File created and text written at: C:\Users\gian\Documents\Evangelista_Activity_5\intro_2025-0295.txt

# %%
# IV. DATA AND OBSERVATION 2

# Read File Content 
from pathlib import Path 
 
student_id = "2025-0295" 
 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
file_path = documents_path / f"intro_{student_id}.txt" 
 
content = file_path.read_text() 
print(content)
# Out:
# Welcome Gian Evangelista (ID: 2025-0295) to File Handling in Python!

# %%
# IV. DATA AND OBSERVATION 3

# Append to a File 
from pathlib import Path 
 
student_id = "2025-0295" 
 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"intro_{student_id}.txt" 
 
with file_path.open("a") as f: 
    f.write("\nThis is a new line.") 
print(f"Line appended to: {file_path}")
# Out:
# Line appended to: C:\Users\gian\Documents\Evangelista_Activity_5\intro_2025-0295.txt

# %%
# IV. DATA AND OBSERVATION 4

# Write Multiple Lines 
from pathlib import Path 
 
student_id = "2025-0295" 
 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
file_path = documents_path / f"lines_{student_id}.txt" 
 
lines = ["Line 1", "Line 2", "Line 3"] 
with file_path.open("w") as f: 
    f.write("\n".join(lines)) 
print(f"Multiple lines written to: {file_path}")
# Out:
# Multiple lines written to: C:\Users\gian\Documents\Evangelista_Activity_5\lines_2025-0295.txt

# %%
# IV. DATA AND OBSERVATION 5

# Read File Line by Line 
from pathlib import Path 
 
student_id = "2025-0295" 
 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"lines_{student_id}.txt" 
 
with file_path.open("r") as f: 
    for line in f: 
        print(line.strip())
# Out:
# Line 1
# Line 2
# Line 3

# %%
# IV. DATA AND OBSERVATION 6

# Count Words in File 
from pathlib import Path 
 
student_id = "2025-0295" 
student_name = "Gian Evangelista" 
 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"lines_{student_id}.txt" 
 
text = file_path.read_text() 
word_count = len(text.split()) 
 
print(f"{student_name} (ID: {student_id}) - Word count in file '{file_path.name}': {word_count}")
# Out:
# Gian Evangelista (ID: 2025-0295) - Word count in file 'lines_2025-0295.txt': 6

# %%
# IV. DATA AND OBSERVATION 7

# Create and Write to a File 
from pathlib import Path 
 
student_id = "2025-0295" 
student_name = "Gian Evangelista" 
 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
documents_path.mkdir(parents=True, exist_ok=True) 
 
file_path = documents_path / f"intro_{student_id}.txt" 
file_path.write_text(f"Welcome {student_name} (ID: {student_id}) to File Handling in Python!") 
 
print(f"File created and text written at: {file_path}")
# Out:
# File created and text written at: C:\Users\gian\Documents\Evangelista_Activity_5\intro_2025-0295.txt

# %%
# IV. DATA AND OBSERVATION 7

# Copy File 
import shutil 
from pathlib import Path 
 
student_id = "2025-0295" 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
 
# Define source and destination 
src = documents_path / f"intro_{student_id}.txt" 
dst = documents_path / f"intro_copy_{student_id}.txt" 
 
# Copy file 
shutil.copy(src, dst) 
print(f"File copied successfully from {src.name} to {dst.name}.")
# Out:
# File copied successfully from intro_2025-0295.txt to intro_copy_2025-0295.txt.

# %%
# IV. DATA AND OBSERVATION 8

# Rename File 
from pathlib import Path 
 
# Personal details (keep consistent per activity) 
student_id = "2025-0295" 
 
# Define directory path 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
 
# Define old and new file paths 
old_file = documents_path / f"intro_copy_{student_id}.txt" 
new_file = documents_path / f"intro_renamed_{student_id}.txt"

# Rename file 
old_file.rename(new_file) 
print(f"File renamed successfully from {old_file.name} to {new_file.name}.")
# Out:
# File renamed successfully from intro_copy_2025-0295.txt to intro_renamed_2025-0295.txt.

# %%
# IV. DATA AND OBSERVATION 9

# Delete File 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 
 
# Define file path 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
file_path = documents_path / f"intro_renamed_{student_id}.txt" 
 
# Check and delete file if it exists 
if file_path.exists(): 
    file_path.unlink() 
    print(f"File deleted successfully from: {file_path}") 
else: 
    print(f"No file found to delete at: {file_path}")
# Out:
# File deleted successfully from: C:\Users\gian\Documents\Evangelista_Activity_5\intro_renamed_2025-0295.txt

# %%
# IV. DATA AND OBSERVATION 10

# Create Directory 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 
 
# Define base and new directory paths 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
new_dir = documents_path / f"data_{student_id}" 
 
# Create the new directory 
new_dir.mkdir(parents=True, exist_ok=True) 
 
print(f"Subdirectory created at: {new_dir}")
# Out:
# Subdirectory created at: C:\Users\gian\Documents\Evangelista_Activity_5\data_2025-0295

# %%
# IV. DATA AND OBSERVATION 11

# Write JSON File 
import json 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 

# Define directory and file path 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
data_dir = documents_path / f"data_{student_id}" 
data_dir.mkdir(parents=True, exist_ok=True) 
 
# Sample data 
data = "Full Name: " "Gian Evangelista", "Age: " "19", "Course: " "Mechanical Engineering"
 
# Write JSON file 
file_path = data_dir / f"student_{student_id}.json" 
with file_path.open("w") as f: 
    json.dump(data, f, indent=4) 
 
print(f"JSON file written at: {file_path}")
# Out:
# JSON file written at: C:\Users\gian\Documents\Evangelista_Activity_5\data_2025-0295\student_2025-0295.json

# %%
# IV. DATA AND OBSERVATION 12

# Read JSON File 
import json 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 
 
# Define the path to the JSON file 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"data_{student_id}" / f"student_{student_id}.json" 
 
# Read and display JSON content 
with file_path.open("r") as f:
     data = json.load(f) 
 
print(data)
# Out:
# ['Full Name: Gian Evangelista', 'Age: 19', 'Course: Mechanical Engineering']

# %%
# IV. DATA AND OBSERVATION 13

# Write CSV File 
import csv 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 
student_name = "Gian Evangelista" 
 
# Define directory and file path 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5" 
file_path = documents_path / f"students_{student_id}.csv"
# Sample data to write
rows = [ 
    ["Name", "Student ID", "Score"], 
    ["Anna", "2025-1001", 90], 
    ["Ben", "2025-1002", 85], 
    [student_name, student_id, 95]   
]
 
# Write CSV file 
with file_path.open("w", newline='') as f: 
    writer = csv.writer(f) 
    writer.writerows(rows) 
 
print(f"CSV file created at: {file_path}")
# Out:
# CSV file created at: C:\Users\gian\Documents\Evangelista_Activity_5\students_2025-0295.csv

# %%
# IV. DATA AND OBSERVATION 14

# Read CSV File 
import csv 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 
 
# Define the file path 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"students_{student_id}.csv" 
 
# Read and display CSV content 
with file_path.open("r") as f: 
    reader = csv.reader(f) 
    for row in reader: 
        print(row)
# Out:
# ['Name', 'Student ID', 'Score']
# ['Anna', '2025-1001', '90']
# ['Ben', '2025-1002', '85']
# ['Gian Evangelista', '2025-0295', '95']

# %%
# IV. DATA AND OBSERVATION 15

# File Not Found Handling 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 
 
# Define a path to a file that does not exist 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"missing_file_{student_id}.txt" 
 
# Attempt to read the file and handle error 
try: 
    print(file_path.read_text()) 
except FileNotFoundError: 
    print(f"File not found for Student ID: {student_id}")
# Out:
# File not found for Student ID: 2025-0295

# %%
# IV. DATA AND OBSERVATION 16

# Count .txt Files 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 
 
# Define directory path 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5" 
 
# Find all .txt files in the directory 
txt_files = list(documents_path.glob("*.txt")) 
 
# Display count and file names 
print(f"Student ID: {student_id}") 
print(f"Found {len(txt_files)} .txt files in {documents_path}") 
for file in txt_files: 
    print(file.name)
# Out:
# Student ID: 2025-0295
# Found 4 .txt files in C:\Users\gian\Documents\Evangelista_Activity_5
# Act5_example.txt
# demo.txt
# intro_2025-0295.txt
# lines_2025-0295.txt

# %%
# IV. DATA AND OBSERVATION 17

# File Metadata 
import os 
import time 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 
 
# Define file path 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"intro_{student_id}.txt" 
 
# Retrieve and display file metadata 
if file_path.exists(): 
    stat = file_path.stat() 
    print(f"Student ID: {student_id}") 
    print(f"File: {file_path.name}") 
    print(f"Size: {stat.st_size} bytes") 
    print(f"Last Modified: {time.ctime(stat.st_mtime)}") 
else: 
    print(f"File {file_path.name} not found for Student ID: {student_id}")
# Out:
# Student ID: 2025-0295
# File: intro_2025-0295.txt
# Size: 68 bytes
# Last Modified: Sun Apr 26 23:48:51 2026

# %%
# IV. DATA AND OBSERVATION 18

# Uppercase and Number Lines 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295" 
 
# Define file path 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"lines_{student_id}.txt" 
 
# Ensure file exists before reading 
if not file_path.exists(): 
    sample_lines = ["Line 1", "Line 2", "Line 3"] 
    file_path.write_text("\n".join(sample_lines)) 
    print(f"Sample file created for Student ID: {student_id}") 
 
# Read, process, and rewrite the file with numbered uppercase lines 
lines = file_path.read_text().splitlines() 
with file_path.open("w") as f: 
    for i, line in enumerate(lines, 1): 
        f.write(f"{i}: {line.upper()}\n") 
 
print(f"Lines formatted and updated in file: {file_path}")
# Out:
# Lines formatted and updated in file: C:\Users\gian\Documents\Evangelista_Activity_5\lines_2025-0295.txt

# %%
# IV. DATA AND OBSERVATION 19

# Reverse File Content 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295"
 
# Define file path 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"lines_{student_id}.txt" 
 
# Ensure file exists before processing 
if not file_path.exists(): 
    sample_lines = ["Line 1", "Line 2", "Line 3"] 
    file_path.write_text("\n".join(sample_lines)) 
    print(f"Sample file created for Student ID: {student_id}") 
 
# Read, reverse, and overwrite the file 
lines = file_path.read_text().splitlines() 
lines.reverse()
# Reverse File Content 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295"
 
# Define file path 
file_path = Path.home() / "Documents" / "Evangelista_Activity_5" / f"lines_{student_id}.txt" 
 
# Ensure file exists before processing 
if not file_path.exists(): 
    sample_lines = ["Line 1", "Line 2", "Line 3"] 
    file_path.write_text("\n".join(sample_lines)) 
    print(f"Sample file created for Student ID: {student_id}") 
 
# Read, reverse, and overwrite the file 
lines = file_path.read_text().splitlines() 
lines.reverse()

print(f"File lines reversed for Student ID: {student_id}")
# Out:
# File lines reversed for Student ID: 2025-0295

# %%
# IV. DATA AND OBSERVATION 20

#  Merge Two Files 
from pathlib import Path 
 
# Personal details 
student_id = "2025-0295"
 
# Define file paths 
documents_path = Path.home() / "Documents" / "Evangelista_Activity_5"
f1 = documents_path / f"intro_{student_id}.txt" 
f2 = documents_path / f"lines_{student_id}.txt" 
merged = documents_path / f"merged_{student_id}.txt" 
 
# Ensure both source files exist 
if not f1.exists(): 
    f1.write_text(f"Welcome {student_id} to File Handling in Python!") 
    print(f"Sample intro file created for Student ID: {student_id}") 
 
if not f2.exists(): 
    f2.write_text("Line 1\nLine 2\nLine 3") 
    print(f"Sample lines file created for Student ID: {student_id}") 
 
# Merge contents of both files 
with merged.open("w") as mf: 
    mf.write(f1.read_text()) 
    mf.write("\n") 
    mf.write(f2.read_text()) 
 
print(f"Files merged successfully for Student ID: {student_id}")
# Out:
# Files merged successfully for Student ID: 2025-0295
