# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\comprog\.venv\lib\site-packages (2.4.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Creating NumPy Arrays
# Step 1: Import NumPy
import numpy as np

# Step 2: Create a 1D array representing years of experience
years_exp = np.array([1, 3, 5, 7, 10, 13])
print("Years of Experience:", years_exp)

# Step 3: Create a 2D array representing sample salaries (in thousands)
salaries = np.array([[20, 30, 40], [ 50, 60, 70], [80, 90, 100,]])
print("Salary Matrix:\n", salaries)

# Step 4: Create an array of zeros and ones for placeholder analysis
zeros_array = np.zeros((2, 2)) # 2x2 zeros
ones_array = np.ones((2, 3)) # 2x3 ones
print("Zeros Array:\n", zeros_array)
print("Ones Array:\n", ones_array)
# Out:
# Years of Experience: [ 1  3  5  7 10 13]
# Salary Matrix:
#  [[ 20  30  40]
#  [ 50  60  70]
#  [ 80  90 100]]
# Zeros Array:
#  [[0. 0.]
#  [0. 0.]]
# Ones Array:
#  [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
# PROCEDURE 2: Array Operations
# Updated: Try It Results
# Step 1: Element-wise subtraction
exp_minus_3 = years_exp - 3 # Subtract 3 years to all experience values
print("Years - 3:", exp_minus_3)

# Step 2: Element-wise division
exp_div_2 = years_exp / 2 # divide all values by 2
print("Years / 2:", exp_div_2)

# Step 3: Dot product (simulate salary projections)
sample1 = np.array([1, 2, 3])
sample2 = np.array([4, 5, 6])
dot_result = np.dot(sample1, sample2)
print("\nDot Product:", dot_result)

# Apply exponential function
np.set_printoptions(precision=4, suppress=True)
exp_values = np.exp(years_exp)
print("\nExponential of years:\n", exp_values)

# Apply logarithmic function
np.set_printoptions(precision=4, suppress=True)
log_salaries = np.log(salaries)
print("\nLogarithm of salaries:\n", log_salaries)
# Out:
# Years - 3: [-2  0  2  4  7 10]
# Years / 2: [0.5 1.5 2.5 3.5 5.  6.5]
#
# Dot Product: 32
#
# Exponential of years:
#  [     2.7183     20.0855    148.4132   1096.6332  22026.4658 442413.392 ]
#
# Logarithm of salaries:
#  [[2.9957 3.4012 3.6889]
#  [3.912  4.0943 4.2485]
#  [4.382  4.4998 4.6052]]

# %%
# PROCEDURE 3: Indexing and Slicing
# Step 1: Access individual element
print("First year of experience:", years_exp[0])

# Step 2: Slice arrays
print("First two salaries:", salaries[0, :2]) # First two elements of first row

# Step 3: Access all rows for a specific column
print("Second column salaries:", salaries[:, 1])

# Step 4: Negative indexing
print("Last year of experience:", years_exp[-1])

# Updated: Try It Results
print("Try It Results:")

# Reverse the 1D years_exp array
reversed_years = years_exp[::-1]
print("\nReversed Years:", reversed_years)

# Get a subgroup: First 2 rows and first 2 columns
salary_subgroup = salaries[0:2, 0:2]
print("\nSalary Subgroup (Top-left 2x2):\n", salary_subgroup)

# Get another subgroup: Last 2 rows and last 2 columns
# (Using negative indexing for fun)
bottom_right = salaries[-2:, -2:]
print("\nSalary Subgroup (Bottom-right):\n", bottom_right)
# Out:
# First year of experience: 1
# First two salaries: [20 30]
# Second column salaries: [30 60 90]
# Last year of experience: 13
# Try It Results:
#
# Reversed Years: [13 10  7  5  3  1]
#
# Salary Subgroup (Top-left 2x2):
#  [[20 30]
#  [50 60]]
#
# Salary Subgroup (Bottom-right):
#  [[ 60  70]
#  [ 90 100]]

# %%
# PROCEDURE 4: Reshaping and Dimensions
# Step 1: Reshape 1D array into 2x3 matrix for batch analysis
reshaped_exp = np.reshape(np.arange(1, 7), (2, 3))
print("Reshaped Experience Array:\n", reshaped_exp)

# Step 2: Flatten 2D arrays back into 1D
flattened_exp = reshaped_exp.flatten()
print("Flattened Array:", flattened_exp)

# Step 3: Transpose example
print("Transposed Array:\n", reshaped_exp.T)

# Updated: Try It Results
data = np.arange(1, 7)

# Reshape to 3 rows and 2 columns
reshaped_3x2 = data.reshape(3, 2)
print("Try It Results:")
print("\nReshaped into 3x2:\n", reshaped_3x2)
# Out:
# Reshaped Experience Array:
#  [[1 2 3]
#  [4 5 6]]
# Flattened Array: [1 2 3 4 5 6]
# Transposed Array:
#  [[1 4]
#  [2 5]
#  [3 6]]
# Try It Results:
#
# Reshaped into 3x2:
#  [[1 2]
#  [3 4]
#  [5 6]]

# %%
# PROCEDURE 5: Broadcasing in NumPy
# Step 1: Add a bonus array to salaries using broadcasting
bonus = np.array([5, 10, 15])
salaries_with_bonus = salaries + bonus # Adds corresponding bonus to each column
print("Salaries after bonus:\n", salaries_with_bonus)

# Updated: Try It Results
scaling_factor = 1.50

# Multiply the entire salaries matrix by the factor
scaled_salaries = salaries * scaling_factor

print("Try It Results:")
print(f"\nSalaries after {scaling_factor} scaling factor:\n", scaled_salaries)
# Out:
# Salaries after bonus:
#  [[ 25  40  55]
#  [ 55  70  85]
#  [ 85 100 115]]
# Try It Results:
#
# Salaries after 1.5 scaling factor:
#  [[ 30.  45.  60.]
#  [ 75.  90. 105.]
#  [120. 135. 150.]]

# %%
# PROCEDURE 6: Statistical Operations
# Step 1: Mean of years of experience
print("Mean experience:", np.mean(years_exp))

# Step 2: Standard deviation of experience
print("Std deviation of experience:", np.std(years_exp))

# Step 3: Max and Min salaries
print("Max salary:", np.max(salaries), "Min salary:", np.min(salaries))

# Step 4: Sum of salaries
print("Sum of all salaries:", np.sum(salaries))

# Updated: Try It Results
# Compute median for years of experience
median_exp = np.median(years_exp)
print("\nTry It Results:")
print("\nMedian experience:", median_exp)

# Compute the 25th and 75th percentiles for salaries
p25 = np.percentile(salaries, 25)
p75 = np.percentile(salaries, 75)

print(f"25th percentile of salaries: {p25}")
print(f"75th percentile of salaries: {p75}")
# Out:
# Mean experience: 6.5
# Std deviation of experience: 4.0722639076235385
# Max salary: 100 Min salary: 20
# Sum of all salaries: 540
#
# Try It Results:
#
# Median experience: 6.0
# 25th percentile of salaries: 40.0
# 75th percentile of salaries: 80.0

# %%
# PROCEDURE 7: NumPy Functions on Arrays
# Step 1: Apply trigonometric functions
angles = np.array([0, np.pi/4, np.pi/2])
print("Sine of angles:", np.sin(angles))
print("Cosine of angles:", np.cos(angles))

# Step 2: Apply function along rows (sum salaries per person)
salary_sums = np.apply_along_axis(np.sum, 1, salaries)
print("Sum of Salaries per person:", salary_sums)

# Updated: Try It Results
# Apply square root to years of experience
sqrt_exp = np.sqrt(years_exp)
print("\nTry It Results:")
print("\nSquare root of experience:", sqrt_exp)

# Define a custom function
def calculate_tax(salary_row):
    return salary_row * 0.10

# Apply it along axis 1 (rows)
tax_per_person = np.apply_along_axis(calculate_tax, 1, salaries)

print("\n10% Tax deduction per person (by row):\n", tax_per_person)
# Out:
# Sine of angles: [0.     0.7071 1.    ]
# Cosine of angles: [1.     0.7071 0.    ]
# Sum of Salaries per person: [ 90 180 270]
#
# Try It Results:
#
# Square root of experience: [1.     1.7321 2.2361 2.6458 3.1623 3.6056]
#
# 10% Tax deduction per person (by row):
#  [[ 2.  3.  4.]
#  [ 5.  6.  7.]
#  [ 8.  9. 10.]]

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\comprog\.venv\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in c:\comprog\.venv\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\comprog\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\comprog\.venv\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\comprog\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# PROCEDURE 8: Integrating NumPy and Pandas for Analysis
import pandas as pd

# Step 1: Create a NumPy array of random data
data = np.random.randint(1, 50, size=(5, 3))

# Step 2: Convert the array into a DataFrame
df_data = pd.DataFrame(data, columns=['X', 'Y', 'Z'])
print("Generated Data:\n", df_data)

# Step 3: Apply NumPy functions to DataFrame columns
df_data['Log_X'] = np.log(df_data['X'])
df_data['Sqrt_Y'] = np.sqrt(df_data['Y'])
print("\nDataFrame with NumPy Transformations:\n", df_data)

# Step 4: Analyze data using Pandas correlation
print("\nCorrelation Matrix:\n", df_data.corr())

# Updated: Try It Results
# Try It: Overall column statistics using NumPy functions
mean_X = np.mean(df_data['X'])
median_Y = np.median(df_data['Y'])

print("\nTry It Results:")
print(f"\nOverall Mean of Column X: {mean_X:.2f}")
print(f"Overall Median of Column Y: {median_Y:.2f}")

# Create a new column by squaring Column Z
df_data['Square_Z'] = np.square(df_data['Z'])

# Create a new column by applying exponential to Column X
df_data['Exp_X'] = np.exp(df_data['X'])

print("\nDataFrame with New Transformations:\n", df_data)
# Out:
# Generated Data:
#      X   Y   Z
# 0  13  30   8
# 1   5  31  40
# 2  10  11  31
# 3  17  43  16
# 4  20  28  42
#
# DataFrame with NumPy Transformations:
#      X   Y   Z     Log_X    Sqrt_Y
# 0  13  30   8  2.564949  5.477226
# 1   5  31  40  1.609438  5.567764
# 2  10  11  31  2.302585  3.316625
# 3  17  43  16  2.833213  6.557439
# 4  20  28  42  2.995732  5.291503
#
# Correlation Matrix:
#                 X         Y         Z     Log_X    Sqrt_Y
# X       1.000000  0.323160 -0.156832  0.978807  0.315736
# Y       0.323160  1.000000 -0.340862  0.237605  0.993948
# Z      -0.156832 -0.340862  1.000000 -0.300041 -0.306614
# Log_X   0.978807  0.237605 -0.300041  1.000000  0.220473
# Sqrt_Y  0.315736  0.993948 -0.306614  0.220473  1.000000
#
# Try It Results:
#
# Overall Mean of Column X: 13.00
# Overall Median of Column Y: 30.00
#
# DataFrame with New Transformations:
#      X   Y   Z     Log_X    Sqrt_Y  Square_Z         Exp_X
# 0  13  30   8  2.564949  5.477226        64  4.424134e+05
# 1   5  31  40  1.609438  5.567764      1600  1.484132e+02
# 2  10  11  31  2.302585  3.316625       961  2.202647e+04
# 3  17  43  16  2.833213  6.557439       256  2.415495e+07
# 4  20  28  42  2.995732  5.291503      1764  4.851652e+08

# %%
# PROCEDURE 9: Importing and Summarizing Data Using Pandas
# Step 1: Save the DataFrame to a CSV file
df_data.to_csv('sample_data.csv', index=False)
print("Data saved to 'sample_data.csv'.")

# Step 2: Load the CSV file back into a new DataFrame
np.set_printoptions(precision=4, suppress=True)
df_imported = pd.read_csv('sample_data.csv')
print("\nImported DataFrame:\n", df_imported)

# Step 3: Generate summary statistics
np.set_printoptions(precision=4, suppress=True)
summary_stats = df_imported.describe()
print("\nSummary Statistics:\n", summary_stats)

# Step 4: Display column means and standard deviations
np.set_printoptions(precision=4, suppress=True)
print("\nColumn Means:\n", df_imported.mean())
print("\nColumn Standard Deviations:\n", df_imported.std())

# Updated: Try It Results
# Try It: Add a new calculated column 'Sum_XY'
np.set_printoptions(precision=4, suppress=True)
df_imported['Sum_XY'] = df_imported['X'] + df_imported['Y']

# Display the updated DataFrame to verify the new column
np.set_printoptions(precision=4, suppress=True)
print("\nUpdated DataFrame with Sum_XY column:\n", df_imported)

# Try It: Save the modified DataFrame to a new file
np.set_printoptions(precision=4, suppress=True)
new_filename = 'modified_sample_data.csv'
df_imported.to_csv(new_filename, index=False)

np.set_printoptions(precision=4, suppress=True)
print(f"\nModified data successfully saved to '{new_filename}'.")
# Out:
# Data saved to 'sample_data.csv'.
#
# Imported DataFrame:
#      X   Y   Z     Log_X    Sqrt_Y  Square_Z         Exp_X
# 0  13  30   8  2.564949  5.477226        64  4.424134e+05
# 1   5  31  40  1.609438  5.567764      1600  1.484132e+02
# 2  10  11  31  2.302585  3.316625       961  2.202647e+04
# 3  17  43  16  2.833213  6.557439       256  2.415495e+07
# 4  20  28  42  2.995732  5.291503      1764  4.851652e+08
#
# Summary Statistics:
#                X          Y          Z     Log_X    Sqrt_Y     Square_Z  \
# count   5.00000   5.000000   5.000000  5.000000  5.000000     5.000000
# mean   13.00000  28.600000  27.400000  2.461184  5.242111   929.000000
# std     5.87367  11.458621  14.926487  0.544413  1.183359   766.427426
# min     5.00000  11.000000   8.000000  1.609438  3.316625    64.000000
# 25%    10.00000  28.000000  16.000000  2.302585  5.291503   256.000000
# 50%    13.00000  30.000000  31.000000  2.564949  5.477226   961.000000
# 75%    17.00000  31.000000  40.000000  2.833213  5.567764  1600.000000
# max    20.00000  43.000000  42.000000  2.995732  6.557439  1764.000000
#
#               Exp_X
# count  5.000000e+00
# mean   1.019569e+08
# std    2.144719e+08
# min    1.484132e+02
# 25%    2.202647e+04
# 50%    4.424134e+05
# 75%    2.415495e+07
# max    4.851652e+08
#
# Column Means:
#  X           1.300000e+01
# Y           2.860000e+01
# Z           2.740000e+01
# Log_X       2.461184e+00
# Sqrt_Y      5.242111e+00
# Square_Z    9.290000e+02
# Exp_X       1.019569e+08
# dtype: float64
#
# Column Standard Deviations:
#  X           5.873670e+00
# Y           1.145862e+01
# Z           1.492649e+01
# Log_X       5.444125e-01
# Sqrt_Y      1.183359e+00
# Square_Z    7.664274e+02
# Exp_X       2.144719e+08
# dtype: float64
#
# Updated DataFrame with Sum_XY column:
#      X   Y   Z     Log_X    Sqrt_Y  Square_Z         Exp_X  Sum_XY
# 0  13  30   8  2.564949  5.477226        64  4.424134e+05      43
# 1   5  31  40  1.609438  5.567764      1600  1.484132e+02      36
# 2  10  11  31  2.302585  3.316625       961  2.202647e+04      21
# 3  17  43  16  2.833213  6.557439       256  2.415495e+07      60
# 4  20  28  42  2.995732  5.291503      1764  4.851652e+08      48
#
# Modified data successfully saved to 'modified_sample_data.csv'.

# %%
import pandas as pd
import numpy as np

# PROCEDURE 10: Data Grouping and Aggregation
# Step 1: Load the dataset (This is now working!)
df_kaggle = pd.read_csv('survey_results_public.csv')

# Step 2: Select columns (Fixed the names to match the CSV)
# Note: In the 2023 survey, compensation is 'ConvertedCompYearly'
df_subset = df_kaggle[['Country', 'EdLevel', 'YearsCodePro', 'ConvertedCompYearly']]

# Step 3: Clean the data
df_clean = df_subset.dropna().copy()

# Step 4: Categorize experience 
# We must convert 'YearsCodePro' to numbers first because it's stored as text
df_clean['YearsCodePro'] = pd.to_numeric(df_clean['YearsCodePro'], errors='coerce')
df_clean = df_clean.dropna() 

df_clean['ExperienceLevel'] = np.where(df_clean['YearsCodePro'] >= 10, 'Senior', 'Junior')

# Step 5 & 6: Group and Reset Index
grouped_data = df_clean.groupby(['Country', 'ExperienceLevel'])['ConvertedCompYearly'].mean()
grouped_data = grouped_data.reset_index()

print("Formatted Grouped Data:\n", grouped_data.head())

# Updated: Try It Results
print("Try It Results:")

# 1. Change the grouping to EdLevel
ed_group = df_clean.groupby('EdLevel')['ConvertedCompYearly'].mean().sort_values(ascending=False)
print("\n1. Average Salary by Education Level:\n", ed_group)

# 2. Compute median and standard deviation
stats_by_country = df_clean.groupby('Country')['ConvertedCompYearly'].agg(['median', 'std'])
print("\n2. Median and Std Dev per Country (Top 5):\n", stats_by_country.head())

# 3. Explore top 10 countries with highest average compensation
top_10_countries = df_clean.groupby('Country')['ConvertedCompYearly'].mean().sort_values(ascending=False).head(10).round(2)
print("\n3. Top 10 Countries by Average Compensation:\n", top_10_countries)
# Out:
# Formatted Grouped Data:
#         Country ExperienceLevel  ConvertedCompYearly
# 0  Afghanistan          Junior         1.031035e+06
# 1  Afghanistan          Senior         3.300000e+01
# 2      Albania          Junior         2.564647e+04
# 3      Albania          Senior         1.397000e+05
# 4      Algeria          Junior         9.103895e+03
# Try It Results:
#
# 1. Average Salary by Education Level:
#  EdLevel
# Primary/elementary school                                                             358681.449761
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                        159445.678094
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          104938.502816
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        97124.658707
# Associate degree (A.A., A.S., etc.)                                                    91136.695003
# Some college/university study without earning a degree                                 90738.206916
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     82310.552747
# Something else                                                                         70794.671674
# Name: ConvertedCompYearly, dtype: float64
#
# 2. Median and Std Dev per Country (Top 5):
#                median           std
# Country
# Afghanistan   1029.5  2.907878e+06
# Albania      13418.5  3.895344e+04
# Algeria       8782.0  6.696098e+03
# Andorra      37481.5  9.101126e+04
# Angola        4302.0  5.147737e+03
#
# 3. Top 10 Countries by Average Compensation:
#  Country
# Mali                        9156199.75
# Afghanistan                  927934.90
# Ethiopia                     722074.92
# Thailand                     634045.58
# Nomadic                      456540.71
# South Africa                 265257.62
# Australia                    176133.19
# United States of America     172583.34
# Switzerland                  134182.30
# Dominica                     132857.00
# Name: ConvertedCompYearly, dtype: float64

# %%
# DATA AND OBSERVATION 1
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
data = np.random.randint(1, STUDENT_ID % 100 + 50, size=10)
print(f"{STUDENT_NAME}'s Array:", data)

mean_val = np.mean(data)
std_val = np.std(data)
print("Mean:", mean_val, "Std Dev:", std_val)
# Out:
# Gian A. Evangelista's Array: [ 92 108  35  83 125  35  93  63  13  90]
# Mean: 73.7 Std Dev: 34.14981698340417

# %%
# DATA AND OBSERVATION 2
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
matrix = np.random.randint(1, STUDENT_ID % 50 + 20, size=(3,4))
print(f"{STUDENT_NAME}'s Matrix:\n", matrix)

row_sums = np.sum(matrix, axis=1)
col_sums = np.sum(matrix, axis=0)
print("Row sums:", row_sums)
print("Column sums:", col_sums)
# Out:
# Gian A. Evangelista's Matrix:
#  [[ 7 64 28 44]
#  [46 35 19 61]
#  [63 35 35 29]]
# Row sums: [143 161 162]
# Column sums: [116 134  82 134]

# %%
# DATA AND OBSERVATION 3
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
arr3d = np.random.randint(0, STUDENT_ID % 20 + 10, size=(3,3,3))
print(f"{STUDENT_NAME}'s 3D Array:\n", arr3d)

slice_mid = arr3d[:,1,:]
print("Slice[:,1,:]:\n", slice_mid)
# Out:
# Gian A. Evangelista's 3D Array:
#  [[[ 6 11 13]
#   [ 2 18  2]
#   [ 2 11 12]]
#
#  [[ 8  9  8]
#   [ 9  7 15]
#   [ 9 10 21]]
#
#  [[ 9  7 16]
#   [ 7  2  7]
#   [14  7 14]]]
# Slice[:,1,:]:
#  [[ 2 18  2]
#  [ 9  7 15]
#  [ 7  2  7]]

# %%
# DATA AND OBSERVATION 4
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
x = np.random.randint(1, STUDENT_ID % 100 + 50, size=10)
filtered = x[(x>STUDENT_ID%50) & (x<STUDENT_ID%100)]
print(f"{STUDENT_NAME}'s Original:", x)
print("Filtered subset:", filtered)
# Out:
# Gian A. Evangelista's Original: [ 92 108  35  83 125  35  93  63  13  90]
# Filtered subset: [92 83 93 63 90]

# %%
# DATA AND OBSERVATION 5
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
A = np.random.randint(1, STUDENT_ID % 50 + 20, size=(2,2))
B = np.random.randint(1, STUDENT_ID % 50 + 20, size=(2,2))
print("Matrix A:\n", A)
print("Matrix B:\n", B)

product = A @ B
det_A = np.linalg.det(A)
print("A @ B:\n", product)
print("Determinant of A:", det_A)
# Out:
# Matrix A:
#  [[ 7 64]
#  [28 44]]
# Matrix B:
#  [[46 35]
#  [19 61]]
# A @ B:
#  [[1538 4149]
#  [2124 3664]]
# Determinant of A: -1484.0

# %%
# DATA AND OBSERVATION 6
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

angles = np.linspace(0, 2*np.pi, 8)
sine_vals = np.sin(angles)
cos_vals = np.cos(angles)
print(f"{STUDENT_NAME}'s Angles:", angles)
print("Sine:", sine_vals)
print("Cosine:", cos_vals)
# Out:
# Gian A. Evangelista's Angles: [0.         0.8975979  1.7951958  2.6927937  3.5903916  4.48798951
#  5.38558741 6.28318531]
# Sine: [ 0.00000000e+00  7.81831482e-01  9.74927912e-01  4.33883739e-01
#  -4.33883739e-01 -9.74927912e-01 -7.81831482e-01 -2.44929360e-16]
# Cosine: [ 1.          0.6234898  -0.22252093 -0.90096887 -0.90096887 -0.22252093
#   0.6234898   1.        ]

# %%
# DATA AND OBSERVATION 7
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
arr = np.random.randint(1, STUDENT_ID % 50 + 20, size=(4,4))
arr[::2, ::2] = 0
print(f"{STUDENT_NAME}'s Modified 4x4 Array:\n", arr)
# Out:
# Gian A. Evangelista's Modified 4x4 Array:
#  [[ 0 64  0 44]
#  [46 35 19 61]
#  [ 0 35  0 29]
#  [44 63 13 41]]

# %%
# DATA AND OBSERVATION 8
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
scores = np.random.randint(0, STUDENT_ID % 100 + 50, 10)
grades = np.where(scores>=STUDENT_ID%70,'Pass','Fail')
print(f"{STUDENT_NAME}'s Scores:", scores)
print("Grades:", grades)
# Out:
# Gian A. Evangelista's Scores: [ 91 107  34  82 124  34  92  62  12  89]
# Grades: ['Pass' 'Pass' 'Fail' 'Pass' 'Pass' 'Fail' 'Pass' 'Pass' 'Fail' 'Pass']

# %%
# DATA AND OBSERVATION 9
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
arr = np.random.randint(1, STUDENT_ID % 50 + 20, size=(3,4))
flat_arr = arr.flatten()
transposed_arr = arr.T
print("Original array:\n", arr)
print("Flattened:", flat_arr)
print("Transposed:\n", transposed_arr)
# Out:
# Original array:
#  [[ 7 64 28 44]
#  [46 35 19 61]
#  [63 35 35 29]]
# Flattened: [ 7 64 28 44 46 35 19 61 63 35 35 29]
# Transposed:
#  [[ 7 46 63]
#  [64 35 35]
#  [28 19 35]
#  [44 61 29]]

# %%
# DATA AND OBSERVATION 10
import numpy as np
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
arr = np.random.randint(1, STUDENT_ID % 50 + 20, (3,3))
mask = arr % 2 == 0
arr[mask] = -1
print("Array with conditional replacements:\n", arr)
# Out:
# Array with conditional replacements:
#  [[ 7 -1 -1]
#  [-1 -1 35]
#  [19 61 63]]

# %%
# DATA AND OBSERVATION 11
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
df = pd.DataFrame({
 'Name': [STUDENT_NAME]*5,
 'Score': np.random.randint(STUDENT_ID%50,
STUDENT_ID%100+50,5),
 'YearsCodePro': np.random.randint(0, STUDENT_ID%20+10,5)
})
print(df)
# Out:
#                   Name  Score  YearsCodePro
# 0  Gian A. Evangelista    115             2
# 1  Gian A. Evangelista    108             2
# 2  Gian A. Evangelista    136            11
# 3  Gian A. Evangelista     79            12
# 4  Gian A. Evangelista    127             8

# %%
# DATA AND OBSERVATION 12
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
df = pd.DataFrame({
'EdLevel': ['Bachelor','Master','PhD','Bachelor','Master'],
# Corrected to use a functional salary range, e.g., 40000 to 150000
'ConvertedComp': np.random.randint(40000, 150000, 5)
})
avg_salary = df.groupby('EdLevel')['ConvertedComp'].mean()
print(avg_salary)
# Out:
# EdLevel
# Bachelor     52056.5
# Master      114992.5
# PhD         113819.0
# Name: ConvertedComp, dtype: float64

# %%
# DATA AND OBSERVATION 13
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
df = pd.DataFrame({
 'Country': ['Philippines','USA','UK','Canada','Germany'],
 'ConvertedComp': np.random.randint(40000, 150000, 5)
})
top5 = df.sort_values(by='ConvertedComp', ascending=False)
print(top5)
# Out:
#        Country  ConvertedComp
# 1          USA         119039
# 2           UK         113819
# 4      Germany         110946
# 0  Philippines          57350
# 3       Canada          46763

# %%
# DATA AND OBSERVATION 14
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
df = pd.DataFrame({
 'Name':[STUDENT_NAME]*5,
 'YearsCodePro': np.random.randint(0, STUDENT_ID%20+10,5)
})
high_exp = df[df['YearsCodePro']>STUDENT_ID%10]
print(high_exp)
# Out:
#                   Name  YearsCodePro
# 0  Gian A. Evangelista             6
# 1  Gian A. Evangelista            11
# 2  Gian A. Evangelista            13
# 4  Gian A. Evangelista            18

# %%
# DATA AND OBSERVATION 15
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
df = pd.DataFrame({'ConvertedComp': np.random.randint(40000,
150000, 5)})
bins = [0, 50000, 100000, 150000, 200000]
labels = ['0-50k', '50-100k', '100-150k', '>150k']
df['Bracket'] = pd.cut(df['ConvertedComp'], bins=bins, labels=labels)
print(df)
# Out:
#    ConvertedComp   Bracket
# 0          57350   50-100k
# 1         119039  100-150k
# 2         113819  100-150k
# 3          46763     0-50k
# 4         110946  100-150k

# %%
# DATA AND OBSERVATION 16
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
# Original Code Issue:
# np.random.randint(STUDENT_ID%40000, STUDENT_ID%150000, 5)
# -> np.random.randint(12345, 12345, 5) which is a zero-length range.
# Corrected Code: Using a functional salary range (40000 to 150000)
df = pd.DataFrame({'ConvertedComp': np.random.randint(40000,
150000, 5)})
df['LogComp'] = np.log(df['ConvertedComp'])
print(df)
# Out:
#    ConvertedComp    LogComp
# 0          57350  10.956928
# 1         119039  11.687206
# 2         113819  11.642365
# 3          46763  10.752848
# 4         110946  11.616799

# %%
# DATA AND OBSERVATION 17
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
df = pd.DataFrame({
'YearsCodePro': np.random.randint(0, STUDENT_ID%20+10, 5),
'ConvertedComp': np.random.randint(40000, 150000, 5)
})
corr_matrix = df.corr()
print(corr_matrix)
# Out:
#                YearsCodePro  ConvertedComp
# YearsCodePro       1.000000      -0.332307
# ConvertedComp     -0.332307       1.000000

# %%
# DATA AND OBSERVATION 18
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)
df = pd.DataFrame({
    'EdLevel':['Bachelor', 'Master', 'PhD', 'Bachelor', 'Master'],
    'ConvertedComp': np.random.randint(40000, 150000, 5)
})

# Calculate mean, median, and standard deviation for each 'EdLevel'
summary = df.groupby('EdLevel')['ConvertedComp'].agg(['mean', 'median', 'std']).reset_index()

print(summary)
# Out:
#     EdLevel      mean    median          std
# 0  Bachelor   52056.5   52056.5  7486.139492
# 1    Master  114992.5  114992.5  5722.615180
# 2       PhD  113819.0  113819.0          NaN

# %%
# DATA AND OBSERVATION 19
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)

# Generate salaries: [100727, 136195, 130612, 100727, 95233]
df = pd.DataFrame({'ConvertedComp': np.random.randint(40000,
150000, 5)})

threshold = 110000

# Create the 'HighPay' column using np.where()
df['HighPay'] = np.where(df['ConvertedComp'] > threshold, 'Yes', 'No')

print(df)
# Out:
#    ConvertedComp HighPay
# 0          57350      No
# 1         119039     Yes
# 2         113819     Yes
# 3          46763      No
# 4         110946     Yes

# %%
# DATA AND OBSERVATION 20
import numpy as np
import pandas as pd
STUDENT_NAME = "Gian A. Evangelista"
STUDENT_ID = 250295

np.random.seed(STUDENT_ID)

df = pd.DataFrame({
'Country': ['Philippines','USA','UK','Canada','Germany'],
'ConvertedComp': np.random.randint(40000, 150000, 5)
})

# Group by 'Country' and calculate the mean and max 'ConvertedComp'
top_countries = df.groupby('Country')['ConvertedComp'].agg(['mean','max'])
print(top_countries)
# Out:
#                  mean     max
# Country
# Canada        46763.0   46763
# Germany      110946.0  110946
# Philippines   57350.0   57350
# UK           113819.0  113819
# USA          119039.0  119039
